# %%
import group_derivatives_3rd as gd

# %%
folder = "/u/vwitzke/datashared/bin_no_VdW/download_for_Miha/"
file = folder + "sorted_buffer.dat"
gd.process_file(file, smooth_window=10)
# Out:
# Processing group: Nband = 0
#   -> chosen degree 11 (score=1.649e-02)
# Group Nband = 0:
#   low  tail: 59 pts (0.036)
#   mid  part: 1556 pts (0.950)
#   high tail: 23 pts (0.014)
#   hit_max_tail_low  = False
#   hit_max_tail_high = False
#   mid split at index 834
#     mid1: 776 pts (0.474)
#     mid2: 781 pts (0.477)
# Processing group: Nband = 1
#   -> chosen degree 11 (score=1.466e-02)
# Group Nband = 1:
#   low  tail: 68 pts (0.144)
#   mid  part: 390 pts (0.828)
#   high tail: 13 pts (0.028)
#   hit_max_tail_low  = False
#   hit_max_tail_high = False
#   mid split at index 306
#     mid1: 239 pts (0.507)
#     mid2: 152 pts (0.323)
# Processing group: Nband = 2
#   -> chosen degree 11 (score=8.867e-03)
# Group Nband = 2:
#   low  tail: 29 pts (0.158)
#   mid  part: 108 pts (0.590)
#   high tail: 46 pts (0.251)
#   hit_max_tail_low  = True
#   hit_max_tail_high = True
#   mid split at index 75
#     mid1: 47 pts (0.257)
#     mid2: 62 pts (0.339)
# ...
